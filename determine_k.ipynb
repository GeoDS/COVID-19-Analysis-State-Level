# %%
from corre import *
# Out:
# Use scipy logsumexp().

# %%
path = "../2yrdata/"
cci=pd.read_csv(path+'two_years_cci.csv',index_col = "date").drop(["Alaska","Hawaii"],axis=1)
cmi=pd.read_csv(path+'two_years_cmi.csv',index_col = "date")
daily = pd.read_csv(path+"two_year_daily.csv",index_col="date",parse_dates=["date"]).drop(["Alaska","Hawaii"],axis=1)

# %%
get_silhouette(10,20,daily)

# %%
get_silhouette(10,20,daily,fname="silhouette2.pdf")

# %%
get_silhouette(10,20,daily,fname="silhouette3.pdf")

# %%
get_silhouette(10,20,daily,fname="silhouette2.pdf")
